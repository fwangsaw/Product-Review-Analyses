# %%
import requests
import pandas as pd
import time
from API_key import API_KEY

# %%
ASIN = "B0014C0LSY"
BASE_URL = "https://real-time-amazon-data.p.rapidapi.com/product-reviews"

# Static header (can be used across all requests)
headers = {
    "X-RapidAPI-Key": API_KEY,
    "X-RapidAPI-Host": "real-time-amazon-data.p.rapidapi.com"
}

# %%
# Change total review pages accordingly
TOTAL_PAGES = 5

# Empty list for storing review data - also used to reset REVIEWS variable if something is off
REVIEWS = []

# %%
# Function to fetch reviews from one page
def fetch_reviews(page):
    querystring = {
        "asin": ASIN,
        "country": "US",
        "page": str(page)
    }
    response = requests.get(BASE_URL, headers=headers, params=querystring)
    if response.status_code == 200:
        return response.json().get("data", {}).get("reviews", [])
    else:
        print(f"Error on page {page}: {response.status_code} | {response.text}")
        return []

# %%
# Loop over pages and parse results
for page in range(1, TOTAL_PAGES + 1):
    page_reviews = fetch_reviews(page)
    # print(type(page_reviews)) # check output type
    # print(page_reviews[0]) # check output first line

    # Total reviews per page
    print(f"Page {page} - Reviews fetched: {len(page_reviews)}") 
    
    for r in page_reviews:
        print("✅ Parsing:", r.get("review_title"))  # Debug print
        REVIEWS.append({
            "reviewer": r.get("review_author"),
            "rating": r.get("review_star_rating"),
            "title": r.get("review_title"),
            "body": r.get("review_comment"),
            "date": r.get("review_date"),
            "verified_purchase": r.get("is_verified_purchase")
        })

    time.sleep(1)  # Respectful delay
# Out:
# Page 1 - Reviews fetched: 10
# ✅ Parsing: Great fit , color , and price.
# ✅ Parsing: Comfort, Durability, and Style – Yellow Crocs are a Game-Changer!
# ✅ Parsing: Great fit, lovely colors and long lasting.  Crocs are a great buy. . . .
# ✅ Parsing: great product
# ✅ Parsing: The kids (teens) love them and wear them daily. As Advertised. Shipped and Received Right Away.
# ✅ Parsing: Great
# ✅ Parsing: A Very Comfortable Shoe All Around
# ✅ Parsing: Newbie Croc wearer answers common questions
# ✅ Parsing: Comfortable, Waterproof Shoes for Summer
# ✅ Parsing: ✨Classic Comfort and Style 👣
# Page 2 - Reviews fetched: 10
# ✅ Parsing: Best Price for Crocs
# ✅ Parsing: I'm sorry I waited and hated for so long!
# ✅ Parsing: The most comfortable pair of shoes I own.
# ✅ Parsing: My kids love them and that's all that matters!
# ✅ Parsing: Seven and a Half Years of Daily Use
# ✅ Parsing: Non-macho shoes..
# ✅ Parsing: Recommend if you are a Croc lover. This color gets compliments!
# ✅ Parsing: Love them!
# ✅ Parsing: Just get them!!!
# ✅ Parsing: Crockin = Rockin
# Page 3 - Reviews fetched: 10
# ✅ Parsing: Comfort wins!!
# ✅ Parsing: Should not have waited 20 years
# ✅ Parsing: love the color
# ✅ Parsing: Well made and so soft.
# ✅ Parsing: A tad too big in length and width but cute and comfy
# ✅ Parsing: Lindos pero guía de tallas equivocada
# ✅ Parsing: Best pair crocs
# ✅ Parsing: Getcha a pair!
# ✅ Parsing: Real
# ✅ Parsing: So cute!
# Page 4 - Reviews fetched: 10
# ✅ Parsing: They changed their sizing!
# ✅ Parsing: Crocs are the best
# ✅ Parsing: Live in my crocs
# ✅ Parsing: Comfortable
# ✅ Parsing: Gatita 🇪🇨
# ✅ Parsing: Love These Crocs
# ✅ Parsing: Very Comfortable
# ✅ Parsing: Dog walker
# ✅ Parsing: Classic Croc's Just What You'd Expect
# ✅ Parsing: Rose pink comfy crocs
# Page 5 - Reviews fetched: 10
# ✅ Parsing: The absolute BEST!!
# ✅ Parsing: Very comfortable
# ✅ Parsing: Great purchase
# ✅ Parsing: Confortables
# ✅ Parsing: COMFORT IS MOST IMPORTANT TO ME
# ✅ Parsing: Swore I’d Never Wear Crocs… Now I Barely Take Them Off
# ✅ Parsing: Good Quality
# ✅ Parsing: Satisfied Customer
# ✅ Parsing: Servicio de primera.
# ✅ Parsing: Crocs

# %%
REVIEWS
# Out:
# [{'reviewer': 'Amazon Customer',
#   'rating': '5',
#   'title': 'Great fit , color , and price.',
#   'body': 'I really like these Crocs. The fit is just right and they’re super comfortable. They are very thick and durable quality and don’t feel flimsy. Easy to put on and take off as well. I also really like the color it looks just like the pictures and they match with everything. The price was good too, especially for how often I wear them. I’d definitely recommend these if you’re thinking about getting a pair.',
#   'date': 'Reviewed in the United States on April 17, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Elliott S.',
#   'rating': '5',
#   'title': 'Comfort, Durability, and Style – Yellow Crocs are a Game-Changer!',
#   'body': 'I’ve been a long-time fan of Crocs, but these yellow ones have truly won me over for both their comfort and style. I’ve worn them on multiple occasions, from casual outings to quick trips around the house, and they’ve held up beautifully while keeping my feet happy the whole time.\n\nThe comfort is unbeatable. The Croslite foam construction offers soft cushioning with every step, making these perfect for extended wear. Whether I’m running errands or standing for long periods, my feet never feel fatigued. The adjustable strap in the back allows for a custom fit, keeping them securely on my feet without feeling too tight. The arch support is surprisingly good for a casual shoe, which is a huge plus.\n\nDespite being made of lightweight material, these Crocs are incredibly durable. I’ve worn them in various environments—wet and dry—and they still look brand new. They’re easy to clean (a quick rinse with water and they’re good to go), and the soles offer excellent traction, making them suitable for both indoor and outdoor use. They’ve handled everything from beach trips to quick walks without showing any signs of wear.\n\nThe bright yellow color is a fun, bold choice. While Crocs are known for their quirky style, I find the yellow to be surprisingly versatile. It’s a cheerful pop of color that can complement a casual summer outfit, or just add a bit of flair to a laid-back day around the house. They’re perfect for anyone who wants to stand out with something more playful and vibrant.\n\nThese yellow Crocs are more than just a fashion statement; they combine comfort, durability, and style in one easy-to-wear shoe. Whether you’re lounging at home, heading to the beach, or running errands, they’re the perfect footwear for effortless, all-day comfort. I couldn’t be happier with my purchase and would highly recommend them to anyone who values comfort and a bit of fun in their footwear!',
#   'date': 'Reviewed in the United States on April 3, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'J. Obrien',
#   'rating': '5',
#   'title': 'Great fit, lovely colors and long lasting.  Crocs are a great buy. . . .',
#   'body': 'If you have never worn Crocs you are missing a wonderful experience.  I wore Croc for years as they were great for a variety of activities, indoor and outdoors.  I gave up my last pair several years ago due to fair wear of the crocs.  i wore them everywhere, indoors and outdoors.  Comfortable and can wear with or without light socks.  I prefer without socks!\nI realized this past month that I really missed having Crocs to wear around the house instead of slippers.  Crocs last a lot longer than slippers!  They may not be as cozy as slippers but wearing them with socks for warmth in the Winter is totally acceptable.  Thank you Amazon for selling this great product in my favorite color of PURPLE, they arrived today and I love them. They are great year round and last a lot longer than slippers even outside!!!',
#   'date': 'Reviewed in the United States on March 9, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Gonzalo ceja',
#   'rating': '5',
#   'title': 'great product',
#   'body': "Got these Crocs for my girlfriend as a surprise, and I might’ve just won the “best boyfriend” award. She’s been talking about wanting a comfy pair for running errands and lounging around, so I picked these up—and now she practically lives in them.\n\nThey’re super lightweight, easy to slip on, and she keeps saying how weirdly comfortable they are (her words, not mine). The cushioning is legit, and the fit was true to size. Plus, she loves the color I picked—bonus points for me.\n\nShe even got a few cute Jibbitz to personalize them, and now they’re her go-to shoes for everything from grocery runs to hanging out on the patio.\n\nIf you're thinking about getting a pair of Crocs for your girl, do it. It’s a small gift that somehow scores big—and hey, happy feet = happy girlfriend 😄💕",
#   'date': 'Reviewed in the United States on April 23, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'miranda schwab',
#   'rating': '5',
#   'title': 'The kids (teens) love them and wear them daily. As Advertised. Shipped and Received Right Away.',
#   'body': 'I have ordered several pairs several times. Typically we have decent luck with size/fitting (we order the M13 & M16) with the original style Crocs brand. Both kids have wide feet and the original are great since some of the other styles are narrower. Nice and lightweight. Both kids wear them nearly everyday so they last pretty well but get a little slick on the bottom if they get worn down a lot. Shipped very fast and arrived the next day. Better price than a lot of places for size and color.',
#   'date': 'Reviewed in the United States on March 29, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Samira Soliman ',
#   'rating': '5',
#   'title': 'Great',
#   'body': 'Very comfortable, slips on easy, I expected the size to be roomy because I sized up, it’s smaller than I expected but still roomy, and useable in multiple places and activities',
#   'date': 'Reviewed in the United States on April 28, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Joy',
#   'rating': '5',
#   'title': 'A Very Comfortable Shoe All Around',
#   'body': 'I love these shoes...They are so comfortable. They are true to size. If you are a women and you wear a size 9, order a 9 because a 10 will be too large. Crocs are easy to slip on and keep on with the strap that can be worn over the shoe or behind the shoe. The styles and designs are nice. They are very durable, easy to keep clean, and the arch support is good. I highly recommend buying Crocs, you will not  regret it.',
#   'date': 'Reviewed in the United States on April 8, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Lacie',
#   'rating': '4',
#   'title': 'Newbie Croc wearer answers common questions',
#   'body': "SIZING + FIT: 1) I wear an exact women’s size 8.5. Sometimes size 9 so I can add a Dr Scholl arch insole.  I ordered these Crocs in two different sizes so I could try them and return the size that didn’t work. The size women’s 9 was too large/loose. The size women’s 8 fit me best, but not perfect.  2) The right shoe is somewhat larger & looser than the left, and the heel strap is longer.  3) I tried inserting a Dr Scholl insole in these Crocs. It did make the shoes more snug on my feet, and added arch support.  The insoles stayed in place.  But, it just felt wrong to put an insole in a Croc shoe since I bought these for orthopedic comfort & support, so I removed them.  4) My husband also just ordered these exact Crocs from Amazon in size Men's 11.  He normally wears a size 10.5 or 11 shoe. They fit him okay, but they are somewhat loose on his narrow feet and he ends up walking duck-footed, with his toes pointed outward, to keep them from slipping.\n\nCOMFORT: 1) After reading A LOT of reviews, I concluded that the comfort of Crocs are unique to each person. People with wider feet seem to really love them. People with foot or back problems love them. People with narrower feet aren’t usually impressed by them.  2) I sit & stand at my desk all day and these shoes are more comfortable than flip flops, but not as comfortable as high quality sneakers.  3) I have high arches and these shoes are tolerable, but don’t really offer much arch support.  Perhaps my feet will eventually mold to the rubber – time will tell.  4) These Crocs have a slight cushioned insole. They are not hard plastic, and the ins
 3 year old grandchild calls them "Nana\'s shoes" and has a pair just like them that she adores.  In fact, I took a good look at my Crocs to be absolutely sure I ordered the exact same ones and noticed that mine, like me I might add, were showing their age quite a bit.  There is little or no tread left on the sole.  I guess the many trips around our acreage, up and down the road, mile after mile, for over 2500 days will do that to a shoe.  The inner sole has been worn smooth as well.  And there is that broken strap... You know, it\'s not even the actual strap... it\'s the little button thing that attaches the strap to the shoe.  Well, in any event, it\'s clearly time for a new pair.  May this pair be a part of many new adventures!',
#   'date': 'Reviewed in the United States on January 23, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'NetMechDB',
#   'rating': '5',
#   'title': 'Non-macho shoes..',
#   'body': "These shoes are so comfortable. This is probably my third pair. I wear them inside of the house. And I did slip on water once. But it's only happened once in the last three years. The downside is, well, they look like Crocs and for a guy. That may be. Tough to handle. To be honest. I don't wear them in front of my friends and even when I check my mail I take them off. And my mailbox is attached to my house right outside my front door. I just can't risk it. It was delivered in a box wrapped in a plastic bag. And even though it was box was wet, the bag was completely dry. New line this is my third pair so I will definitely buy more. As needed, I use them for recovery from plantar fasciitis.",
#   'date': 'Reviewed in the United States on March 24, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'M',
#   'rating': '5',
#   'title': 'Recommend if you are a Croc lover. This color gets compliments!',
#   'body': 'This color is pretty. I get so many compliments and requests to purchase them for others as a gift. I was glad to finally find this color available as I had been waiting for it to be back in stock. They are so nice to slip on in rain to do errands or take the dog out. They are same quality as always for the brand. Recommend if you like crocs, or garden shoes.',
#   'date': 'Reviewed in the United States on April 25, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'J',
#   'rating': '5',
#   'title': 'Love them!',
#   'body': 'This is my second pair of these after wearing down my first pair. The first pair lasted 2 plus years. The new pair seems identical to the old. So far the new pair has been great. Hope the new pair lasts just as long!',
#   'date': 'Reviewed in the United States on May 4, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Kenna92',
#   'rating': '5',
#   'title': 'Just get them!!!',
#   'body': 'Obviously you can never go wrong with crocs! My goal is to own every color & my husband thinks I’m crazy 🤪🤪🤪\nComfort, arch support, convenience, durability, easy to clean, water proof, decorate w/charms, plantar fasciitis friendly, multi gender, strap optional, everythinggg!!!',
#   'date': 'Reviewed in the United States on May 5, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Brandon garrison',
#   'rating': '5',
#   'title': 'Crockin = Rockin',
#   'body': 'If you ain’t crockin you ain’t rockin. Funny how everyone made fun of me for pulling my old dogs out (old crocs). Then everyone seemed to be wearing them around me… weirddd. These are a fantastic upgrade. Make sure you go in 4 wheel drive when running from the po po.',
#   'date': 'Reviewed in the United States on May 1, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Grace T',
#   'rating': '5',
#   'title': 'Comfort wins!!',
#   'body': 'I’m so happy with my new Crocs. This is my first pair and it won’t be my last. They’re comfortable, lightweight and perfect for my lifestyle.\nNow I know why my grandkids are so crazy about them.',
#   'date': 'Reviewed in the United States on May 2, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Robert I. Thomas',
#   'rating': '5',
#   'title': 'Should not have waited 20 years',
#   'body': "Comfy, non-sweaty, easy on and off, but don't fall off. They are great to wear around the house and deck, and even out to the mailbox.  But I wouldn't go farther.\n\nI chose the baby-blue version because they were on sale.\n\nI used to work for a regional retailer that sold tons of Crocks, but I never tried them until I got these. I missed out.",
#   'date': 'Reviewed in the United States on April 20, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'karen laudisio',
#   'rating': '5',
#   'title': 'love the color',
#   'body': 'they are crocs so they feel good on the feet. I bought this loud color for my husband because he had two black pair and never remembered which ones were inside or outside shoes. now he knows. BLUE is inside. lol keeps floors much cleaner',
#   'date': 'Reviewed in the United States on April 29, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'T R Smith',
#   'rating': '4',
#   'title': 'Well made and so soft.',
#   'body': 'I love my Crocs. I wear them all the time. Super flexible and supportive on my feet. I just recently had a somewhat small issue that developed. It seems that one of the shoes, right where my toes and my foot meet, the shoe is starting to delaminate there, or it\'s like a small "bubble" that fits right in that part of my foot, under my toes joints of three toes, so that it feels like something is in my shoe and I\'m stepping on it. It\'s soft, so it doesn\'t hurt. It\'s just annoying. I\'m barefoot when I wear these, so I likely wouldn\'t feel it if I wore socks or put a liner inside. I just prefer not to do so. But all in all, I\'m still happy with them.',
#   'date': 'Reviewed in the United States on April 4, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'junebride',
#   'rating': '4',
#   'title': 'A tad too big in length and width but cute and comfy',
#   'body': "Wish these came in half sizes. I'm a 10.5 so the 10s are slightly too short and the 11s are a little big and wide. My feet are very skinny with no meat on them so they wiggle a little and fit better with socks though not how I want to wear them. But with that said, I still like them and find them comfy. The color is nice and neutral so it goes with any color clothing you wear.",
#   'date': 'Reviewed in the United States on April 27, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Laura Contreras',
#   'rating': '5',
#   'title': 'Lindos pero guía de tallas equivocada',
#   'body': 'Me llegó el color y la talla que pedí (W9/M7) sin embargo me quedó grande, no los voy a devolver por que son para usar en la casa, sin embargo la tabla de tallas está equivocada ya que decía que la talla que seleccioné era para un pie de 23.8 cm de largo y mi pide mide 24.0 cm y me quedó grande, creo que una o incluso dos tallas menos me hubiera quedado perfecta',
#   'date': 'Reviewed in the United States on April 15, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Lovely Lozin ',
#   'rating': '5',
#   'title': 'Best pair crocs',
#   'body': 'In love with crocs and this one is one of the best I ever got. Need them in every color. They are so cute and comfy. I even had a pair for my mother.',
#   'date': 'Reviewed in the United States on April 28, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'JamieinremoteOR',
#   'rating': '5',
#   'title': 'Getcha a pair!',
#   'body': "These are my first pair of real Crocs brand crocs (instead of the cheapo knock-offs)\nThey're much more well-made with clearly better material.\nBut in my case, the size (mens 10 US) is a little large.  They're fine with socks though.\nAnd they're really comfy too.\nI rate this a great purchase.",
#   'date': 'Reviewed in the United States on April 24, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Jane In Austin',
#   'rating': '5',
#   'title': 'Real',
#   'body': 'Real crocs at a good price! Real crocs have more arch support than most lookalikes, plus the quality of craftsmanship is better. I’ve paid this price for knockoffs before, so u highly recommend these.',
#   'date': 'Reviewed in the United States on May 5, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Emily',
#   'rating': '5',
#   'title': 'So cute!',
#   'body': 'The quartz Crocs are sold out every time I check the Crocs website. So happy to find them on here, below retail! They are so cute and comfy. They have saved my feet as a housekeeper during my pregnancy and am so happy to have another pair now!',
#   'date': 'Reviewed in the United States on April 21, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Christina',
#   'rating': '4',
#   'title': 'They changed their sizing!',
#   'body': 'I am an avid croc wearer. Wear them basically everyday. My last pair, I bought about 1.5-2 years ago, lost the tread on the bottom so it was time for a new pair. Ordered these and they were quite a bit snugger. I thought it was all in my head. It had bought the same size as last time but I thought it was in my head. I went to a local shoe store to get something and the salesperson confirmed that she also recently had to get a new pair and she had to size up as well. So just be aware that if it’s been a while since you got a pair, you may need to size up.',
#   'date': 'Reviewed in the United States on April 6, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Esmeralda ',
#   'rating': '5',
#   'title': 'Crocs are the best',
#   'body': 'As a person who uses crocs every time this is a must have. They are super comfortable and it also comes in different sizes and colors. I really recommend it',
#   'date': 'Reviewed in the United States on May 6, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Kay Dee',
#   'rating': '5',
#   'title': 'Live in my crocs',
#   'body': 'I live crocs. I stand on my feet 8 hours a day and I fiind these the most comfortable.\nI fit this color bc it was on sale . It’s a very light neutral pink .',
#   'date': 'Reviewed in the United States on April 29, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Chris',
#   'rating': '5',
#   'title': 'Comfortable',
#   'body': 'I initially didn’t consider buying these ever but some family members and co workers highly recommended them. So I ordered a couple pairs. I really like that they are roomy and very comfortable. I like them so much that I will probably pick up some different colors. I will add that I like the ones with the vent holes much more than the work ones without the holes.',
#   'date': 'Reviewed in the United States on April 10, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Gatita Ecuador',
#   'rating': '5',
#   'title': 'Gatita 🇪🇨',
#   'body': 'Perfectos son originales talla color perfectas trae todo los logos de la marca soy talla 39 me quedó perfecta la  talla 6 M. 8 W',
#   'date': 'Reviewed in the United States on May 6, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Alex',
#   'rating': '5',
#   'title': 'Love These Crocs',
#   'body': 'Absolutely love my Crocs! They’re super comfortable, easy to slip on, and perfect for everyday wear. Great support and super easy to clean—my go-to shoes now!',
#   'date': 'Reviewed in the United States on April 13, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'N Dale',
#   'rating': '5',
#   'title': 'Very Comfortable',
#   'body': 'I put off buying Crocs, but the more I thought about the lightness and roominess they could provide, I decided to try them. I wasn’t disappointed!',
#   'date': 'Reviewed in the United States on April 14, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Tonya',
#   'rating': '5',
#   'title': 'Dog walker',
#   'body': 'I wear crocs to walk my dog and there perfect for that. I love the comfort and the fact they’re waterproof and easy clean.',
#   'date': 'Reviewed in the United States on April 30, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Milton C',
#   'rating': '5',
#   'title': "Classic Croc's Just What You'd Expect",
#   'body': "They're Croc's, they fit, they're the same as the 10 year old pair they replaced.  Better price than at a local retailer. I love these for indoor wear all year round.  Just put on a pair of socks in the winter and I'm good to go.  More support than flip flops so my feet don't hurt at the end of the day.",
#   'date': 'Reviewed in the United States on March 6, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Loved this top the material was nice and thick love that I can style top two different ways.',
#   'rating': '5',
#   'title': 'Rose pink comfy crocs',
#   'body': 'Loved my pink crocs pink is my favorite color it’s not a dark pink more of a rose pink so cute and comfy.',
#   'date': 'Reviewed in the United States on March 26, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Bear',
#   'rating': '5',
#   'title': 'The absolute BEST!!',
#   'body': 'I swore I would NEVER wear a pair of crocs…. Until I actually wore a pair of crocs.  Now they are my go to casual shoes and perfect when my feet are tired after a long day of work!  Now, I’ve got my wife hooked on em too!',
#   'date': 'Reviewed in the United States on April 1, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Sammy',
#   'rating': '5',
#   'title': 'Very comfortable',
#   'body': 'Great crocs but after wearing everyday for a year they get a little stretched out lol. Still quite comfortable thou great purchase. Definitely worth it',
#   'date': 'Reviewed in the United States on April 24, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'TJ',
#   'rating': '5',
#   'title': 'Great purchase',
#   'body': 'Fits great! Super comfy. Easy to put on and take off. Slightly less grippy after a little over 1 year but otherwise still going strong.',
#   'date': 'Reviewed in the United States on April 10, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'DIANA VILLAMIZAR',
#   'rating': '5',
#   'title': 'Confortables',
#   'body': 'Muy buenos, firmes pero confortables, hay que tener cuidado en algunos suelos porque se frenan y es como si tropezaran pero depende de la superficie',
#   'date': 'Reviewed in the United States on April 29, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Linda',
#   'rating': '5',
#   'title': 'COMFORT IS MOST IMPORTANT TO ME',
#   'body': 'I FOUND THEM TO BE VERY COMFORTABLE, I LIKE THE STYLE, IM 61 YRS OLD WITH A BAD BACK SO I HAVE TO BE SELECTIVE WHEN WEARING OR BUYING ANY SHOES.THEY LOOK AND FEEL VERY DURABLE, I CAN WALK IN THEM JUST FINE,A GREAT VALUE FOR YOUR MONEY!!!',
#   'date': 'Reviewed in the United States on April 8, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'JRA7',
#   'rating': '5',
#   'title': 'Swore I’d Never Wear Crocs… Now I Barely Take Them Off',
#   'body': 'I used to laugh at Crocs. “Not me,” I said. “Never.” Then, in a moment of weakness, I slipped my feet into a pair. Now? I wear them anywhere and everywhere…errands, the backyard, even places where I probably shouldn’t be wearing Crocs but do anyway. Comfort over pride, folks. Easy to clean, ridiculously comfortable, and somehow the most practical shoe in existence. If you’re on the fence, just give in. Resistance is futile.\n\nWould I buy another pair?… I already have.',
#   'date': 'Reviewed in the United States on March 26, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Hannah',
#   'rating': '5',
#   'title': 'Good Quality',
#   'body': 'Just what we expected. My kids wear crocs just about every single day. They are holding up great with all the use!',
#   'date': 'Reviewed in the United States on April 18, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'ScarterWil',
#   'rating': '5',
#   'title': 'Satisfied Customer',
#   'body': 'Never been disappointed when it comes to Crocs and this bright red pair were received with satisfaction!  Great price and comfortable!',
#   'date': 'Reviewed in the United States on April 9, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'ricardo juarez',
#   'rating': '5',
#   'title': 'Servicio de primera.',
#   'body': 'Excelente servicio, entrega a tiempo y superó mis expectativas, muy satisfecho con el servicio de entrega por eso le doy 5 esteellas!!!',
#   'date': 'Reviewed in the United States on April 28, 2025',
#   'verified_purchase': True},
#  {'reviewer': 'Angelie',
#   'rating': '5',
#   'title': 'Crocs',
#   'body': 'First crocs I owe. I bought one because I hurt my ankle and my foot was really swollen. They alright I guess.',
#   'date': 'Reviewed in the United States on April 19, 2025',
#   'verified_purchase': True}]

# %%
# Convert to DataFrame
df = pd.DataFrame(REVIEWS)
print(df.head())
# Out:
#           reviewer rating                                              title  \
# 0  Amazon Customer      5                     Great fit , color , and price.
# 1       Elliott S.      5  Comfort, Durability, and Style – Yellow Crocs ...
# 2        J. Obrien      5  Great fit, lovely colors and long lasting.  Cr...
# 3     Gonzalo ceja      5                                      great product
# 4   miranda schwab      5  The kids (teens) love them and wear them daily...
#
#                                                 body  \
# 0  I really like these Crocs. The fit is just rig...
# 1  I’ve been a long-time fan of Crocs, but these ...
# 2  If you have never worn Crocs you are missing a...
# 3  Got these Crocs for my girlfriend as a surpris...
# 4  I have ordered several pairs several times. Ty...
#
#                                               date  verified_purchase
# 0  Reviewed in the United States on April 17, 2025               True
# 1   Reviewed in the United States on April 3, 2025               True
# 2   Reviewed in the United States on March 9, 2025               True
# 3  Reviewed in the United States on April 23, 2025               True
# 4  Reviewed in the United States on March 29, 2025               True

# %%
# Save to CSV
df.to_csv("crocs_reviews_real_time_amazon.csv", index=False)
